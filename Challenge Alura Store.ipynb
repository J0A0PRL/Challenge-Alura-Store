# %%
# Relatório Final de Análises das Lojas

## Introdução

Este relatório sintetiza as análises realizadas para apoiar a decisão sobre **qual loja o Senhor João deve vender**.
Foram considerados: faturamento total, categorias mais e menos vendidas, avaliações médias dos clientes,
produtos mais e menos vendidos e o custo médio de frete. As conclusões se baseiam nos dados dos arquivos
fornecidos (loja_1 a loja_4) e nas visualizações geradas ao longo do estudo.

## Principais Resultados por Loja

### Loja 1

- **Faturamento:** R$ 1.534.509,12
- **Avaliação média:** 3.98 ⭐
- **Frete médio:** R$ 34,69
- **Categoria mais vendida:** moveis (465 vendas)
- **Categoria menos vendida:** utilidades domesticas (171 vendas)
- **Produto mais vendido:** TV Led UHD 4K (60 unidades)
- **Produto menos vendido:** Headset (33 unidades)

### Loja 2

- **Faturamento:** R$ 1.488.459,06
- **Avaliação média:** 4.04 ⭐
- **Frete médio:** R$ 33,62
- **Categoria mais vendida:** moveis (442 vendas)
- **Categoria menos vendida:** utilidades domesticas (181 vendas)
- **Produto mais vendido:** Iniciando em programação (65 unidades)
- **Produto menos vendido:** Jogo de tabuleiro (32 unidades)

### Loja 3

- **Faturamento:** R$ 1.464.025,03
- **Avaliação média:** 4.05 ⭐
- **Frete médio:** R$ 33,07
- **Categoria mais vendida:** moveis (499 vendas)
- **Categoria menos vendida:** instrumentos musicais (177 vendas)
- **Produto mais vendido:** Kit banquetas (57 unidades)
- **Produto menos vendido:** Blocos de montar (35 unidades)

### Loja 4

- **Faturamento:** R$ 1.384.497,58
- **Avaliação média:** 4.00 ⭐
- **Frete médio:** R$ 31,28
- **Categoria mais vendida:** moveis (480 vendas)
- **Categoria menos vendida:** instrumentos musicais (170 vendas)
- **Produto mais vendido:** Cama box (62 unidades)
- **Produto menos vendido:** Guitarra (33 unidades)

## Visualizações

- **Faturamento por loja:** ![](/mnt/data/faturamento_por_loja.png)
- **Distribuição de categorias (Loja 1):** ![](/mnt/data/categorias_loja1.png)
- **Custo médio de frete por loja:** ![](/mnt/data/frete_medio_por_loja.png)

## Discussão

- **Faturamento:** A liderança de faturamento é da Loja 1, seguida por Loja 2 e Loja 3; a **Loja 4 apresenta o menor faturamento**.
- **Satisfação (avaliações):** As melhores médias estão em **Loja 3** e **Loja 2** (ambas levemente acima de 4,0), enquanto Loja 1 e Loja 4 ficam muito próximas de 4,0.
- **Frete médio:** A **Loja 4 tem o menor custo médio de frete**, porém isso não se traduz em maior faturamento. A Loja 1 tem o maior frete médio e ainda assim é líder em receita.
- **Mix de categorias e produtos:** O padrão de categorias mais fortes (Móveis e Eletrônicos) se repete em todas as lojas, sem uma diferenciação competitiva clara da Loja 4.

## Recomendação e Justificativa

**Recomendação:** vender a **Loja 4**.

**Justificativa:**
- A Loja 4 é a que **menos fatura**, o que reduz a contribuição para o resultado consolidado.
- Sua **avaliação média** não é a melhor do grupo, indicando **menor vantagem competitiva em experiência** do cliente frente a Loja 2 e Loja 3.
- Apesar do **frete médio mais baixo**, o benefício **não compensa o gap de receita**, e o mix de categorias não apresenta um nicho superior aos concorrentes internos.
- Manter as lojas com **maior faturamento e/ou melhor satisfação** (Loja 1, Loja 2 e Loja 3) tende a maximizar o resultado futuro e preservar a base de clientes mais satisfeita.
